# %% [markdown]
# # HCDT Quickstart
#
# Welcome to the Human-Centered Digital Twin (HCDT) for multihazard research.
#
# **Data setup:** Download data from DesignSafe and place under `data/raw/`:
# - PRJ-2113 (Michael)
# - PRJ-5770 (Ian-BD)

# %%
import hcdt
print(f"HCDT version: {hcdt.__version__}")
